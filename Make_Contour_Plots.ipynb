# %% [markdown]
# Import all of the libraries we need for this project

# %%
import aplpy as apl
import astropy as ap
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Start by defining the NUV, VLA, GBT fits files directories

# %%
NUV_DIR='/Users/lucashunt/ASTRODATA/STARBIRDS/NUV_Images/'
VLA_DIR='/Users/lucashunt/ASTRODATA/STARBIRDS/VLA_Mom0/'
GBT_DIR='/Users/lucashunt/ASTRODATA/STARBIRDS/GBT_FITS/'

# %% [markdown]
# Next we want to get a list of all of the files in each of the directories

# %%
GBT_FITS=os.listdir(GBT_DIR)
VLA_FITS=os.listdir(VLA_DIR)
NUV_FITS=os.listdir(NUV_DIR)

# %%
VLA_FITS=[f for f in VLA_FITS if f.startswith('fixed')]

# %%
VLA_FITS
# Out:
# ['fixed_DDO165_NA_X0_P_R.FITS',
#  'fixed_DDO187_NA_X0_P_R.FITS',
#  'fixed_DDO50_NA_X0_P_R.FITS',
#  'fixed_M81DWA_NA_X0_P_R.FITS',
#  'fixed_NGC1569_NA_X0_P_R.FITS',
#  'fixed_NGC2366_NA_X0_P_R.FITS',
#  'fixed_NGC4068_FR-I-21cm-h2002.fits',
#  'fixed_NGC625_ATCA_mom0.fits',
#  'fixed_NGC672_FR-I-21cm-h2002.fits',
#  'fixed_NGC784_FR-I-21cm-h2002.fits',
#  'fixed_NGC_2403_NA_MOM0_THINGS.FITS',
#  'fixed_NGC_3627_NA_MOM0_THINGS.FITS',
#  'fixed_VIIZw403_NA_X0_P_R.FITS',
#  'fixed_VLA-ANGST_HI_UGC4483-nat-Mom0.fits']

# %%
print(GBT_FITS)
print(VLA_FITS)
VLA_TO_GBT_DICT={'fixed_DDO165_NA_X0_P_R.FITS':'D165_GBT_OLD_mom0_copy.fits','fixed_DDO187_NA_X0_P_R.FITS':'D187_GBT_CUBE_4CH_mom0.fits','fixed_DDO50_NA_X0_P_R.FITS':'D50-U4483_GBT_TRANS_VEL_mom0.fits','fixed_M81DWA_NA_X0_P_R.FITS':'D50-U4483_GBT_TRANS_VEL_mom0.fits','fixed_NGC1569_NA_X0_P_R.FITS':'NGC1569-U92_mom0.fits','fixed_NGC2366_NA_X0_P_R.FITS':'N2366-lf-all_GBT_mom0.fits','fixed_NGC4068_FR-I-21cm-h2002.fits':'N4068_GBT_mom0.fits','fixed_NGC625_ATCA_mom0.fits':'N625_all_baseline_hanning_mom0.fits','fixed_NGC672_FR-I-21cm-h2002.fits':'N672-MOS_mom0.fits','fixed_NGC784_FR-I-21cm-h2002.fits':'fixed_N784-MOS_mom0.fits','fixed_VLA-ANGST_HI_UGC4483-nat-Mom0.fits':'D50-U4483_GBT_TRANS_VEL_mom0.fits'}

#VLA_TO_GBT_DICT={'M81DWA_NA_X0_P_R.FITS':'D50-U4483_GBT_TRANS_VEL_mom0.fits','NGC1569_NA_X0_P_R.FITS':'NGC1569-U92_mom0.fits','NGC2366_NA_X0_P_R.FITS':'N2366-lf-all_GBT_mom0.fits','NGC4068_FR-I-21cm-h2002.fits':'N4068_GBT_mom0.fits','NGC625_ATCA_mom0.fits':'N625_all_baseline_hanning_mom0.fits','NGC672_FR-I-21cm-h2002.fits':'N672-MOS_mom0.fits','NGC784_FR-I-21cm-h2002.fits':'N784-MOS_mom0.fits','VLA-ANGST_HI_UGC4483-nat-Mom0.fits':'D50-U4483_GBT_TRANS_VEL_mom0.fits'}

for VLA_FILE in VLA_TO_GBT_DICT:
    print(VLA_DIR+VLA_FILE)
    print(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
# Out:
# ['.DS_Store', 'D165_GBT_OLD_mom0_copy.fits', 'D187_GBT_CUBE_4CH_mom0.fits', 'D50-U4483_GBT_TRANS_VEL_mom0.fits', 'DDO165_GBT_OLD_mom0.fits', 'E154-G023_baseline_LD_WGTMED_mom0.fits', 'E410-G005_all_baseline_hanning_mom0.fits', 'IC4662_all_baseline_hanning_mom0.fits', 'IC5152_all_baseline_hanning_mom0.fits', 'N2366-lf-all_GBT_mom0.fits', 'N2366-rt-cloud_GBT_mom0.fits', 'N2366-rt-nomw-gal_GBT_mom0.fits', 'N4068_GBT_mom0.fits', 'N625_all_baseline_hanning_mom0.fits', 'N672-MOS_mom0.fits', 'N6789_GBT_mom0.fits', 'N6789_GBT_mom0_updatecrval.fits', 'N6822_GBT_mom0.fits', 'N784-MOS_mom0.fits', 'NGC1569-U92_mom0.fits', 'SoFiA_Starbirds.zip', 'TESTING_UPDATED_HEADER_APLPY.fits', 'U86-IC342_mom0.fits']
# ...

# %%
for VLA_FILE in VLA_TO_GBT_DICT:
    print(VLA_FILE)
    gc=apl.FITSFigure(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
    plt.rcParams['axes.facecolor']='black'
    gd=apl.FITSFigure(VLA_DIR+VLA_FILE)
#    gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
#    hdu=ap.io.fits.open(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
    gc.show_grayscale()
    gd.show_grayscale()
    gc.show_contour(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE],colors='yellow')
    gd.show_contour()
#    gd.add_beam()
#    gd.add_beam()
#    gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
#    gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
#    gd.beam[1].set_angle(float(hdu[0].header['BPA']))
#    gd.beam[1].set_color('yellow')
#    gd.beam[1].set_corner('bottom right')
#    gd.beam[0].show()
    gd.set_title(VLA_TO_GBT_DICT[VLA_FILE])
# Out:
# M81DWA_NA_X0_P_R.FITS
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# INFO: Auto-setting vmin to -2.094e+01 [aplpy.core]
# INFO: Auto-setting vmax to  2.297e+02 [aplpy.core]
# INFO: Auto-setting vmin to -4.936e+00 [aplpy.core]
# INFO: Auto-setting vmax to  5.479e+01 [aplpy.core]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-c209905435f1> in <module>
#       9     gd.show_grayscale()
#      10     gc.show_contour(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE],colors='yellow')
# ---> 11     gd.show_contour()
#      12 #    gd.add_beam()
#      13 #    gd.add_beam()
#
# ...

# %%
for VLA_FILE in VLA_TO_GBT_DICT:
    print(VLA_FILE)
    gc=apl.FITSFigure(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
    plt.rcParams['axes.facecolor']='black'
    gd=apl.FITSFigure(VLA_DIR+VLA_FILE)
    gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
    hdu=ap.io.fits.open(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
    gc.show_grayscale()
    gd.show_grayscale()
    gd.show_contour(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE],colors='yellow')
    gd.add_beam()
    gd.add_beam()
    gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
    gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
    gd.beam[1].set_angle(float(hdu[0].header['BPA']))
    gd.beam[1].set_color('yellow')
    gd.beam[1].set_corner('bottom right')
    gd.beam[0].show()
    gd.set_title('VLA_FILE')
# Out:
# M81DWA_NA_X0_P_R.FITS
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE4 from 'FELO-HEL' to 'VOPT-F2W', and SPECSYS to 'BARYCENT' (VELREF=2)'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cb53e944dcb9> in <module>
#       4     plt.rcParams['axes.facecolor']='black'
#       5     gd=apl.FITSFigure(VLA_DIR+VLA_FILE)
# ----> 6     gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
#       7     hdu=ap.io.fits.open(GBT_DIR+VLA_TO_GBT_DICT[VLA_FILE])
#       8     gc.show_grayscale()
#
# ~/programs/anaconda3/anaconda3/lib/python3.6/site-packages/aplpy/core.py in pixel2world(self, xp, yp, wcs)
#    1910         if wcs is None:
#    1911             wcs = self._wcs
# ...

# %%
#print(GBT_FITS)
#print(VLA_FITS)
gc=apl.FITSFigure(GBT_DIR+'D187_GBT_CUBE_4CH_mom0.fits')
plt.rcParams['axes.facecolor']='black'
gd=apl.FITSFigure(VLA_DIR+'DDO187_NA_X0_P_R.FITS')
gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
hdu=ap.io.fits.open(GBT_DIR+'D187_GBT_CUBE_4CH_mom0.fits')
print(hdu[0].header['BMAJ'])
#gc=apl.FITSFigure(VLA_DIR+VLA_FITS[0])
#gd=apl.FITSFigure(GBT_DIR+GBT_FITS[1])
#print(gc.pixel2world(17,17))
#print(VLA_FITS[0],GBT_FITS[1])
#gc.recenter(radius=1)
gc.show_grayscale()
gd.show_grayscale()
gd.show_contour(GBT_DIR+'D187_GBT_CUBE_4CH_mom0.fits',colors='yellow')
gd.add_beam()
gd.add_beam()
#gd.beam[0].show()
print(gd.beam)
gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
gd.beam[1].set_angle(float(hdu[0].header['BPA']))
gd.beam[1].set_color('yellow')
gd.beam[1].set_corner('bottom right')
gd.beam[0].show()
gd.set_title('DDO 187')
gd.save('/Users/lucashunt/ASTRODATA/STARBIRDS/APLPY_Images/Contour_plots/DDO187_CONTOUR.png')
# Out:
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE4 from 'FELO-HEL' to 'VOPT-F2W', and SPECSYS to 'BARYCENT' (VELREF=2)'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5700ecedf87e> in <module>
#       4 plt.rcParams['axes.facecolor']='black'
#       5 gd=apl.FITSFigure(VLA_DIR+'DDO187_NA_X0_P_R.FITS')
# ----> 6 gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
#       7 hdu=ap.io.fits.open(GBT_DIR+'D187_GBT_CUBE_4CH_mom0.fits')
#       8 print(hdu[0].header['BMAJ'])
#
# ~/programs/anaconda3/anaconda3/lib/python3.6/site-packages/aplpy/core.py in pixel2world(self, xp, yp, wcs)
#    1910         if wcs is None:
#    1911             wcs = self._wcs
# ...

# %%
GBT_FITS=os.listdir(GBT_DIR)
VLA_FITS=os.listdir(VLA_DIR)
NUV_FITS=os.listdir(NUV_DIR)
#print(GBT_FITS)
#print(VLA_FITS)
gc=apl.FITSFigure(GBT_DIR+'DDO165_GBT_OLD_mom0.fits')
plt.rcParams['axes.facecolor']='black'
gd=apl.FITSFigure(VLA_DIR+'DDO165_NA_X0_P_R.FITS')
gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
hdu=ap.io.fits.open(GBT_DIR+'DDO165_GBT_OLD_mom0.fits')
print(hdu[0].header['BMAJ'])
#gc=apl.FITSFigure(VLA_DIR+VLA_FITS[0])
#gd=apl.FITSFigure(GBT_DIR+GBT_FITS[1])
#print(gc.pixel2world(17,17))
#print(VLA_FITS[0],GBT_FITS[1])
#gc.recenter(radius=1)
gc.show_grayscale()
gd.show_grayscale()
gd.show_contour(GBT_DIR+'DDO165_GBT_OLD_mom0.fits',colors='yellow')
gd.add_beam()
gd.add_beam()
#gd.beam[0].show()
print(gd.beam)
gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
gd.beam[1].set_angle(float(hdu[0].header['BPA']))
gd.beam[1].set_color('yellow')
gd.beam[1].set_corner('bottom right')
gd.beam[0].show()
gd.set_title('DDO 165')
gd.save('/Users/lucashunt/ASTRODATA/STARBIRDS/APLPY_Images/Contour_plots/DDO165_CONTOUR.png')
# Out:
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# INFO: Setting slices=[0, 0] [aplpy.core]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE4 from 'FELO-HEL' to 'VOPT-F2W', and SPECSYS to 'BARYCENT' (VELREF=2)'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-027f079329bf> in <module>
#       7 plt.rcParams['axes.facecolor']='black'
#       8 gd=apl.FITSFigure(VLA_DIR+'DDO165_NA_X0_P_R.FITS')
# ----> 9 gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
#      10 hdu=ap.io.fits.open(GBT_DIR+'DDO165_GBT_OLD_mom0.fits')
#      11 print(hdu[0].header['BMAJ'])
#
# ~/programs/anaconda3/anaconda3/lib/python3.6/site-packages/aplpy/core.py in pixel2world(self, xp, yp, wcs)
#    1910         if wcs is None:
#    1911             wcs = self._wcs
# ...

# %%
GBT_FITS=os.listdir(GBT_DIR)
VLA_FITS=os.listdir(VLA_DIR)
NUV_FITS=os.listdir(NUV_DIR)
#print(GBT_FITS)
#print(VLA_FITS)
gc=apl.FITSFigure(GBT_DIR+'N672-MOS_mom0.fits')
plt.rcParams['axes.facecolor']='black'
gd=apl.FITSFigure(VLA_DIR+'NGC672_FR-I-21cm-h2002.fits')
#gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
hdu=ap.io.fits.open(GBT_DIR+'N672-MOS_mom0.fits')
print(hdu[0].header['BMAJ'])
#gc=apl.FITSFigure(VLA_DIR+VLA_FITS[0])
#gd=apl.FITSFigure(GBT_DIR+GBT_FITS[1])
#print(gc.pixel2world(17,17))
#print(VLA_FITS[0],GBT_FITS[1])
#gc.recenter(radius=1)
gc.show_grayscale()
gd.show_grayscale()
gd.show_contour(GBT_DIR+'N672-MOS_mom0.fits',colors='yellow')
gd.add_beam()
gd.add_beam()
#gd.beam[0].show()
print(gd.beam)
gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
gd.beam[1].set_angle(float(hdu[0].header['BPA']))
gd.beam[1].set_color('yellow')
gd.beam[1].set_corner('bottom right')
gd.beam[0].show()
gd.set_title('NGC 672')
gd.save('/Users/lucashunt/ASTRODATA/STARBIRDS/APLPY_Images/Contour_plots/NGC672.png')
# Out:
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: DATE-OBS= 1993.568
# a string value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'unitfix' made the change 'Changed units: 'DEGREE' -> 'deg', 'DEGREE' -> 'deg''. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# INFO: Setting slices=[0] [aplpy.core]
# 0.14521
# INFO: Auto-setting vmin to -5.195e+00 [aplpy.core]
# INFO: Auto-setting vmax to  5.427e+01 [aplpy.core]
# INFO: Auto-setting vmin to -2.931e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.355e+01 [aplpy.core]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-aa662ad74736> in <module>
#      17 gc.show_grayscale()
#      18 gd.show_grayscale()
# ...

# %%
GBT_FITS=os.listdir(GBT_DIR)
VLA_FITS=os.listdir(VLA_DIR)
NUV_FITS=os.listdir(NUV_DIR)
#print(GBT_FITS)
#print(VLA_FITS)
gc=apl.FITSFigure(GBT_DIR+'N784-MOS_mom0.fits')
plt.rcParams['axes.facecolor']='black'
gd=apl.FITSFigure(VLA_DIR+'NGC784_FR-I-21cm-h2002.fits')
#gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
hdu=ap.io.fits.open(GBT_DIR+'N784-MOS_mom0.fits')
print(hdu[0].header['BMAJ'])
#gc=apl.FITSFigure(VLA_DIR+VLA_FITS[0])
#gd=apl.FITSFigure(GBT_DIR+GBT_FITS[1])
#print(gc.pixel2world(17,17))
#print(VLA_FITS[0],GBT_FITS[1])
#gc.recenter(radius=1)
gc.show_grayscale()
gd.show_grayscale()
gd.show_contour(GBT_DIR+'N784-MOS_mom0.fits',colors='yellow')
gd.add_beam()
gd.add_beam()
#gd.beam[0].show()
print(gd.beam)
gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
gd.beam[1].set_angle(float(hdu[0].header['BPA']))
gd.beam[1].set_color('yellow')
gd.beam[1].set_corner('bottom right')
gd.beam[0].show()
gd.set_title('NGC 784')
gd.save('/Users/lucashunt/ASTRODATA/STARBIRDS/APLPY_Images/Contour_plots/NGC784.png')
# Out:
# INFO: Setting slices=[0] [aplpy.core]
# 0.14521
# INFO: Auto-setting vmin to -1.634e+00 [aplpy.core]
# INFO: Auto-setting vmax to  1.736e+01 [aplpy.core]
# INFO: Auto-setting vmin to -1.116e+01 [aplpy.core]
# INFO: Auto-setting vmax to  8.866e+01 [aplpy.core]
# [<aplpy.overlays.Beam object at 0x104a9bc50>, <aplpy.overlays.Beam object at 0x1817339d30>]

# %%
print(GBT_FITS)
print('****************************')
print(VLA_FITS)
# Out:
# ['.DS_Store', 'D165_GBT_OLD_mom0_copy.fits', 'D187_GBT_CUBE_4CH_mom0.fits', 'DDO165_GBT_OLD_mom0.fits', 'E154-G023_baseline_LD_WGTMED_mom0.fits', 'E410-G005_all_baseline_hanning_mom0.fits', 'IC4662_all_baseline_hanning_mom0.fits', 'IC5152_all_baseline_hanning_mom0.fits', 'N2366-lf-all_GBT_mom0.fits', 'N2366-rt-cloud_GBT_mom0.fits', 'N2366-rt-nomw-gal_GBT_mom0.fits', 'N4068_GBT_mom0.fits', 'N625_all_baseline_hanning_mom0.fits', 'N672-MOS_mom0.fits', 'N6789_GBT_mom0.fits', 'N6789_GBT_mom0_updatecrval.fits', 'N6822_GBT_mom0.fits', 'N784-MOS_mom0.fits', 'NGC1569-U92_mom0.fits', 'SoFiA_Starbirds.zip', 'TESTING_UPDATED_HEADER_APLPY.fits', 'U86-IC342_mom0.fits']
# ****************************
# ...

# %%
GBT_FITS=os.listdir(GBT_DIR)
VLA_FITS=os.listdir(VLA_DIR)
NUV_FITS=os.listdir(NUV_DIR)
#print(GBT_FITS)
#print(VLA_FITS)
gc=apl.FITSFigure(GBT_DIR+'NGC1569-U92_mom0.fits')
plt.rcParams['axes.facecolor']='black'
gd=apl.FITSFigure(VLA_DIR+'NGC1569_NA_X0_P_R.FITS')
#gd.recenter(gd.pixel2world(512,512)[0],gd.pixel2world(512,512)[1],radius=0.5)
hdu=ap.io.fits.open(GBT_DIR+'NGC1569-U92_mom0.fits')
#print(hdu[0].header['BMAJ'])
#gc=apl.FITSFigure(VLA_DIR+VLA_FITS[0])
#gd=apl.FITSFigure(GBT_DIR+GBT_FITS[1])
#print(gc.pixel2world(17,17))
#print(VLA_FITS[0],GBT_FITS[1])
#gc.recenter(radius=1)
gc.show_grayscale()
gd.show_grayscale()
gd.show_contour(GBT_DIR+'NGC1569-U92_mom0.fits',colors='yellow')
gd.add_beam()
gd.add_beam()
#gd.beam[0].show()
print(gd.beam)
#gd.beam[1].set_major(float(hdu[0].header['BMAJ']))
#gd.beam[1].set_minor(float(hdu[0].header['BMIN']))
#gd.beam[1].set_angle(float(hdu[0].header['BPA']))
#gd.beam[1].set_color('yellow')
#gd.beam[1].set_corner('bottom right')
gd.beam[0].show()
gd.set_title('NGC 1569')
gd.save('/Users/lucashunt/ASTRODATA/STARBIRDS/APLPY_Images/Contour_plots/NGC784.png')
# Out:
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'spcfix' made the change 'Changed CTYPE4 from 'FELO-HEL' to 'VOPT-F2W', and SPECSYS to 'BARYCENT' (VELREF=2)'. [astropy.wcs.wcs]
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -6.927e+00 [aplpy.core]
# INFO: Auto-setting vmax to  7.689e+01 [aplpy.core]
# INFO: Auto-setting vmin to -5.562e+00 [aplpy.core]
# INFO: Auto-setting vmax to  5.764e+01 [aplpy.core]
# WARNING: FITSFixedWarning: 'celfix' made the change 'Success'. [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-8e5b88b31985> in <module>
#      17 gc.show_grayscale()
#      18 gd.show_grayscale()
# ---> 19 gd.show_contour(GBT_DIR+'NGC1569-U92_mom0.fits',colors='yellow')
#      20 gd.add_beam()
#      21 gd.add_beam()
#
# ...
